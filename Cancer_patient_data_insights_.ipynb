# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import seaborn as sns
from google.colab import files

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_excel('/content/drive/MyDrive/Colab Notebooks/cancer patient data sets.xlsx',engine ='openpyxl')

# %% [markdown]
# # New Section

# %%
print(df.head())
# Out:
#   Patient Id  Age  Gender  Air Pollution  Alcohol use  Dust Allergy  \
# 0         P1   33       1              2            4             5
# 1        P10   17       1              3            1             5
# 2       P100   35       1              4            5             6
# 3      P1000   37       1              7            7             7
# 4       P101   46       1              6            8             7
#
#    OccuPational Hazards  Genetic Risk  chronic Lung Disease  Balanced Diet  \
# 0                     4             3                     2              2
# 1                     3             4                     2              2
# 2                     5             5                     4              6
# 3                     7             6                     7              7
# 4                     7             7                     6              7
#
#    ...  Fatigue  Weight Loss  Shortness of Breath  Wheezing  \
# ...

# %%
#sns.barplot(y='Smoking',x='Gender',data = df)
sns.lineplot(x='Obesity',y='Fatigue',data=df)
# Out:
# <Axes: xlabel='Obesity', ylabel='Fatigue'>

# %%
df['Gender-in-str'] = df['Gender'].map({1:'Male',2:'Female'})

# %%
sns.barplot(y='Smoking',x='Gender-in-str',data = df)
# Out:
# <Axes: xlabel='Gender-in-str', ylabel='Smoking'>

# %%
print(df)
sns.barplot(y='Level',x='Shortness of Breath',data=df)
# Out:
#      Age  Air Pollution  Alcohol use  Dust Allergy  OccuPational Hazards  \
# 0     33              2            4             5                     4
# 1     17              3            1             5                     3
# 2     35              4            5             6                     5
# 3     37              7            7             7                     7
# 4     46              6            8             7                     7
# ..   ...            ...          ...           ...                   ...
# 995   44              6            7             7                     7
# 996   37              6            8             7                     7
# 997   25              4            5             6                     5
# 998   18              6            8             7                     7
# 999   47              6            5             6                     5
#
#      Genetic Risk  chronic Lung Disease  Balanced Diet  Obesity  Smoking  ...  \
# ...

# %%
df = df.drop(columns=['Patient Id', 'Gender']) # Added 'Gender' to the columns list
df['Level'] = df['Level'].map({'Low':1,'Medium':2,'High':3})
sns.heatmap(df.corr()[['Level']],annot=True)
# Out:
# <Axes: >

# %%
sns.lineplot(x='Level',y='Dry Cough',data=df)
# Out:
# <Axes: xlabel='Level', ylabel='Dry Cough'>

# %%
sns.violinplot(x='Air Pollution',y='chronic Lung Disease',data=df)
# Out:
# <Axes: xlabel='Air Pollution', ylabel='chronic Lung Disease'>
